# %% [markdown]
# # Optimize synthetic data parameters for IID/Cluster pass but Spatial fail at Δ=1
#
# This notebook runs a stochastic search using your current local modules.

# %%
# import sys
# sys.path.insert(0, '.')
# sys.path.insert(0, '/mnt/data')
from pyTOST.data_gen.optimize_spatial_params import search, save_best

# %%
best, hist = search(
    seed=123,
    n_iter=400,
    alpha=0.05,
    margin=1.0,
    verbose_every=1)
best
# Out:
# [   1/400] searching best_score=1e+06 eq(iid,clu,spa)=(False,False,False) CI_spa=(nan, nan)
# [   2/400] searching best_score=1e+06 eq(iid,clu,spa)=(False,False,False) CI_spa=(nan, nan)
# [   3/400] searching best_score=1e+06 eq(iid,clu,spa)=(False,False,False) CI_spa=(nan, nan)
# [   4/400] searching best_score=1e+06 eq(iid,clu,spa)=(False,False,False) CI_spa=(nan, nan)
# [   5/400] searching best_score=1e+06 eq(iid,clu,spa)=(False,False,False) CI_spa=(nan, nan)
# [   6/400] searching best_score=5 eq(iid,clu,spa)=(True,True,True) CI_spa=(0.9426722293269288, 0.9593359016083649)
# [   7/400] searching best_score=5 eq(iid,clu,spa)=(True,True,True) CI_spa=(0.9426722293269288, 0.9593359016083649)
# [   8/400] searching best_score=5 eq(iid,clu,spa)=(True,True,True) CI_spa=(0.9426722293269288, 0.9593359016083649)
# [   9/400] searching best_score=5 eq(iid,clu,spa)=(True,True,True) CI_spa=(0.9426722293269288, 0.9593359016083649)
# ...

# %%
best.params['df_diff'].to_csv('spatial_df_diff.csv', index=False)

# %%
# Out:
# /Users/dhetting/src/pyTOST

# %%
save_best(best, 'best_spatial_params.json')
print('Wrote best_spatial_params.json')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 save_best(best, 'best_spatial_params.json')
#       2 print('Wrote best_spatial_params.json')
#
# File ~/src/pyTOST/pyTOST/data_gen/optimize_spatial_params.py:550, in save_best(best, path, alpha, margin)
#     532 payload = {
#     533     "ok_pattern": bool(best.ok_pattern),
#     534     "score": float(best.score),
#    (...)    547     "notes": best.notes,
#     548 }
#     549 with open(path, "w", encoding="utf-8") as f:
# --> 550     json.dump(payload, f, indent=2, sort_keys=True)
#
# File /opt/miniconda3/envs/pytost/lib/python3.14/json/__init__.py:181, in dump(obj, fp, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     175     iterable = cls(skipkeys=skipkeys, ensure_ascii=ensure_ascii,
# ...

# %%
import pandas as pd

df = pd.DataFrame([{
    'score': r.score,
    'ok_pattern': r.ok_pattern,
    'eq_iid': r.eq_iid,
    'eq_cluster': r.eq_cluster,
    'eq_spatial': r.eq_spatial,
    'ci_iid': r.ci_iid,
    'ci_cluster': r.ci_cluster,
    'ci_spatial': r.ci_spatial,
    **{k:v for k,v in r.params.items() if k!='_meta'}
} for r in hist])

df.sort_values(['ok_pattern','score'], ascending=[False, True]).head(20)
